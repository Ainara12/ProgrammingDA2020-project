# %% [markdown]
# ### Draft version of PAD project
#
# Using this notebook as draft version of PAD project.
#
# ***
# References used:
#
# [Pandas documentation about aggregate functions](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html)
#
# ***

# %%
#Creating dataframe as done in the documentation referenced above: 
import pandas as pd
import numpy as np


df = pd.DataFrame((np.random.randint(1,30,120),
                   (np.random.randint(np.random.randint(1,30,120)*2),
                    (np.random.randint(1,30,120)*4))
    
df.agg(['March','April','May'])                  
                   
print(df)
# Out:
#   File "<ipython-input-1-39ed9196d2af>", line 10
#     df.agg(['March','April','May'])
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <br>
#
# ### Attempt using tadpoles dataset:
#
# Since this project is being a burden and I need to get it done . I am trying now a new attempt to create synthetic data and analyse as needed.  Find below the references for this attempt , instructions for this project and the markdown explaining the process and steps taken along with the code cells.

# %% [markdown]
# <br>
#
# ### Instructions
#
# #### **Problem statement**:
#
# For this project you must create a data set by simulating a real-world phenomenon of
# your choosing. You may pick any phenomenon you wish – you might pick one that is
# of interest to you in your personal or professional life. Then, rather than collect data
# related to the phenomenon, you should model and synthesise such data using Python.
# We suggest you use the numpy.random package for this purpose.
#
# Specifically, in this project you should:
# - Choose a real-world phenomenon that can be measured and for which you could
#   collect at least one-hundred data points across at least four different variables.
#
# - Investigate the types of variables involved, their likely distributions, and their
#    relationships with each other.
#
# - Synthesise/simulate a data set as closely matching their properties as possible.
#
# - Detail your research and implement the simulation in a Jupyter notebook – the
#     data set itself can simply be displayed in an output cell within the notebook.
#     Note that this project is about simulation – you must synthesise a data set. Some
#     students may already have some real-world data sets in their own files. It is okay to
#     base your synthesised data set on these should you wish (please reference it if you do),
#     but the main task in this project is to create a synthesised data set. The next section
#     gives an example project idea

# %% [markdown]
# ***
# References:
#
# -[Example dataset extracted from this source](https://vincentarelbundock.github.io/Rdatasets/articles/data.html)
#
# -[Numpy random rand function documentation](https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html)
#
# -[Pandas loc function documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
#
# -[]()
#
#
#
#
# ***

# %% [markdown]
# <br>
#
# ### Analysing inspiration dataset
#
# I have found very complicated to try to create bigger and more complex datasets. For the time being, I am using a smaller dataset extracted from this [list of R datasets](https://vincentarelbundock.github.io/Rdatasets/articles/data.html).
# The original dataset consist of 27 observations on 4 variables which compare intestine length for tadpoles with and without exposure to a fungus called (Batrachochytrium dendrobatidis (Bd)).
#
# The purpose of this studio was to determine whether tadpoles can adjust the relative length of their intestines if they are exposed to said fungus.
#
# The 4 Variables that this dataset shows are :
# - Treatment: This is a categorical variable that defines whether the tadpole was exposed to the fungus (Bd=yes) or no (Control=no)
#
# - Body: Represents the length of the animal body in mm.
#
# - Intestine_Length: Is the length of the intestine in mm.
#
# - MouthpartDamage: Measure of damage to the mouth.
#
# My reason to choose this real world example is that I am really interested on the animal world and I found this was an unusual dataset and have curiosity to see the distribution of it and how we can reproduce it and make assumptions or predictions based on it.
#
# Before I create my synthetic data, let's have a look into this dataset using pandas and matplotlib library.

# %%
#first I imported the necessary modules for this section

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading data

tpoles_dataset= pd.read_csv('Tadpoles_dataset.csv',delimiter=',')

tpolesdf=pd.DataFrame(data=tpoles_dataset, columns=['Treatment','Body','Intestine_Length', 'MouthpartDamage'])

tpolesdf
# Out:
#    Treatment   Body  Intestine_Length  MouthpartDamage
# 0         Bd  20.28            191.40            0.679
# 1         Bd  19.75            142.92            0.607
# 2         Bd  19.28            169.81            0.750
# 3         Bd  17.81            152.18            0.821
# 4         Bd  20.79            171.33            0.696
# 5         Bd  16.99            153.92            0.571
# 6         Bd  18.12            181.08            0.571
# 7         Bd  16.95            124.90            0.571
# 8         Bd  19.45            173.06            0.679
# 9         Bd  19.44            207.01            0.786
# 10        Bd  18.32            143.77            0.750
# 11        Bd  20.27            220.35            0.714
# 12        Bd  18.71            130.00            0.714
# 13        Bd  19.05            195.13            0.714
# 14   Control  19.46            177.92            0.421
# 15   Control  22.62            181.58            0.546
# ...

# %%
#Plotting raw dataset in facetGrid

sns.FacetGrid(tpolesdf,hue="Treatment",size=3).map(sns.distplot,"Body").add_legend()
sns.FacetGrid(tpolesdf,hue="Treatment",size=3).map(sns.distplot,"Intestine_Length").add_legend()
sns.FacetGrid(tpolesdf,hue="Treatment",size=3).map(sns.distplot,"MouthpartDamage").add_legend()

plt.show()
# Out:
# C:\Users\fainl\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\fainl\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\fainl\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# <br>
#
# Looking at the plots above, which are separated by the 3 variables , while different colors compare the tadpoles that had contact with fungus (Bd label) to the ones that did not(Control label). We can observe that the distribution seems to follow in all cases a bell shape. Let's then try to reproduce this in our synthetic dataset and try to get to a conclusion seeing the relationship between the body parts taken into account and the exposure or no exposure to the fungus.

# %%
#Creating data :

#we import numpy module to create random samples of floats
import numpy as np

np.random.seed(10)

Body_measures_withfungus=np.random.uniform(low=16.00, high=19.00, size=(60))
Body_measures_nofungus=np.random.uniform(low=19.00, high=26.00, size=(60))
Intestine_length=np.random.uniform(low=120.00, high=250.00, size=120)
Mouth_damage=np.random.uniform(low=0.54, high=0.87, size=120)

#Printing these values

print('Random samples for body length (in mm) for tadpoles in contact with the fungus:')
print(Body_measures_withfungus)

print('--------------------------------------------------------')

print('Random samples for body length (in mm) for tadpoles not in contact with the fungus:')
print(Body_measures_nofungus)

print('--------------------------------------------------------')

print('Random samples for intestine length (in mm) for tadpoles:')
print(Intestine_length)

print('--------------------------------------------------------')

print('Random samples for mouth damage for tadpoles :')
print(Mouth_damage)
# Out:
# Random samples for body length (in mm) for tadpoles in contact with the fungus:
# [18.31396193 16.06225585 17.9009447  18.24641165 17.49552104 16.67438994
#  16.59418859 18.28159214 16.50733251 16.26501944 18.05607946 18.86018004
#  16.0118448  17.53657679 18.43786288 17.8375782  18.16526595 16.8756282
#  18.75332237 18.14372735 17.6276331  16.42651014 17.12002228 18.02240085
#  17.32549952 17.30204198 17.85330094 17.53941473 17.95119155 17.80311686
#  18.41566959 17.56494146 18.72594664 16.95770827 16.27137805 16.90210017
                            0.75873118, 0.8487711,  0.74220063, 0.8181037,  0.61190978, 0.83804667,
                            0.54322409, 0.6145182,  0.58357819, 0.83948917, 0.84037611, 0.73174911]})



print(df)
# Out:
#     Contact_with_fungus  Body_Length  Intestine_Length  Mouth_Damage
# 0                   Yes    18.313962        148.440015      0.639069
# 1                   Yes    16.062256        217.824502      0.670826
# 2                   Yes    17.900945        133.894346      0.801780
# 3                   Yes    18.246412        216.798421      0.676051
# 4                   Yes    17.495521        181.072088      0.601006
# 5                   Yes    16.674390        197.773237      0.817282
# 6                   Yes    16.594189        139.190625      0.727860
# 7                   Yes    18.281592        143.924527      0.559817
# 8                   Yes    16.507333        203.859376      0.866343
# 9                   Yes    16.265019        126.321641      0.615498
# 10                  Yes    18.056079        152.319626      0.742852
# 11                  Yes    18.860180        190.513107      0.661449
# 12                  Yes    16.011845        149.480535      0.804916
# ...

# %% [markdown]
# <br>
#
# Now I am using the loc function to access  to a group of values using labels.

# %%
#Checking which datatypes are every elements of the dataset created
df.dtypes
# Out:
# Contact_with_fungus     object
# Body_Length            float64
# Intestine_Length       float64
# Mouth_Damage           float64
# dtype: object

# %%
#Accessing to categories using  loc function 

Contact_fungus=df.loc[df['Contact_with_fungus']=='Yes']
No_contact_fungus=df.loc[df['Contact_with_fungus']=='No']


#print(Contact_fungus)

#print(No_contact_fungus)
# Out:
#     Contact_with_fungus  Body_Length  Intestine_Length  Mouth_Damage
# 60                   No    23.181602        182.922716      0.768286
# 61                   No    25.319822        229.770153      0.602380
# 62                   No    22.741906        142.725806      0.804992
# 63                   No    23.131410        121.902534      0.709872
# 64                   No    19.274972        230.339329      0.789904
# 65                   No    21.500272        216.547695      0.598670
# 66                   No    19.557292        179.370680      0.567265
# 67                   No    21.138219        174.196793      0.699084
# 68                   No    21.315035        135.174836      0.714522
# 69                   No    24.416812        164.028287      0.769782
# 70                   No    19.279714        132.305675      0.607571
# 71                   No    22.006445        213.058013      0.761553
# 72                   No    21.204488        130.021103      0.801779
# ...

# %%
#Plotting synthetic dataset using seaborn

sns.catplot(x='Contact_with_fungus', y='Intestine_Length', data=df)
plt.show()

# %%
#Using boxplot now:

sns.catplot(x='Contact_with_fungus', y='Intestine_Length', kind="box",  data=df)
plt.show()

# %%
#Using a different type of plot as cannot see the information there too clearly

sns.catplot(x='Contact_with_fungus', y='Body_Length', data=df)
plt.show()

# %%
#Plotting synthetic dataset using seaborn bar chart

sns.pairplot(data=df, hue='Contact_with_fungus')

# %%
#using boxplot to see if values for mouth damage are in any way varying when tadpole is in contact with the fungus

sns.catplot(x='Contact_with_fungus', y='Mouth_Damage', kind="box",  data=df)
plt.show()

# %%
#Adding data to a DataFrame

# %% [markdown]
# <br>
#
# ### Creating dataset using alternative method
#
# In this section of this project I would like to create some synthetic data using an specific package for Python called 'Faker' . See steps below:

# %%
#I installed Faker and imported module
from faker import Faker
fake= Faker()


#information gathered from this source:
    
    '''https://pypi.org/project/Faker/'''
